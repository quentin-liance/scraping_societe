# %%
import pandas as pd
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
from urllib.request import URLopener

# %%
# Enterprise list
url_list : list[str] = ["https://www.societe.com/societe/france-croco-501737761.html"]

# Prepare empty Array 
globalDf = []
my_ent = []

# 1  define own years range 

startYear = 2018
endYear = 2020
# 2  Create function to get website data (bilan) 
def gen_soup(url: str):
    req = Request(url, headers={'User-Agent': 'Safari'}) # changer le navigateur éventuellement (ça ne change pas grand chose)
    webpage = urlopen(req).read()
    return bs(webpage,"html.parser") # renvoie le code HTML

# %%
tables_rows = gen_soup(url=url_list[0]).findAll("table")
tables_rows
# Out:
# [<table class="Table identity mt-16" id="rensjur"><tr><td class="arrow">Date création entreprise</td><td class="flex space-between flex-wrap"><div class="TableTexteGauche"><span class="TableTextGenerique"> 17-12-2007 </span><span class="TableTextDetail"><span class="show-mobile-inline-l"> - </span>il y a 16 ans </span></div><span class="TableLienDroite"><a class="Lien with-picto" href="https://www.societe.com/documents-officiels/france-croco-501737761.html#statutshop"><span>Statuts constitutifs</span><i class="material-icons-outlined">chevron_right</i></a></span></td></tr><tr class="Paywall"><td class="arrow" colspan="2"><div class="FicheDonnees__around imrFirst" id="catjur-histo-around"><div class="FicheDonnees" id="catjur-histo" onclick="show_historique_donnees('catjur-histo-voir')"><div class="abonne-compteplus donneesHistoriques voirPlus" id="catjur-histo-voir"><p class="Lien with-picto"><span class="hide-mobile-inline-l">Historique</span><span class="show-mobile-inline-l">Voir l'historique</span><i class="material-icons-outlined">expand_more</i></p></div><div class="FicheDonnees__libelle">Forme juridique </div><div class="FicheDonnees__donneeGenerique ml-6" id="catjur-histo-description">SASU Société par actions simplifiée à associé unique </div><div class="FicheDonnees__donneeGenerique soPrimaryColor2 ml-6 isHidden" id="catjur-histo-libelle">Historique </div></div><div class="FicheDonnees__historique noOpacity nocompteplus" id="catjur-histo-content"><div class="histo-part" id="catjur-histo-content-src-rcs"><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du 11-11-2016</p><p>à aujourd'hui </p><p class="soBaseColor-600 italic">7 ans, 1 mois et 21 jours </p></div><div class="FicheDonnees__timeline first"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description first newoffers"><span class="description-txt">SASU Société par actions simplifiée à associé unique</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXXX X XXXX XX XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXXX X XXXX XX XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXX XX X XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="compteplus historiqueDonneesAffiliationDesktop newoffers"><div class="AutopromoPlus__promo inTable newoffers"><span class="AutopromoPlus__icon"><i class="material-icons-outlined">rocket_launch</i></span><p class="AutopromoPlus__text">Version limitée. Pour en voir plus, faites évoluer votre offre. </p><p class="flex center"><a class="CtaButton text reverse mr-8" href="https://paiement.societe.com/cgi-bin/compte-login">Se connecter</a><a class="CtaButton reverse" href="/offres.html" onclick="gana_event(this.href, 'Conversion', 'SocietePlus', 'catjur im ...
#  <table class="Table simple no-bg"><tr><td class="no-padding arrow">Téléphone</td><td class="Paywall"><div class="Lien" data-annunrlead="" data-compteplus="nocompteplus" data-siret="50173776100020" data-src="rensjur" id="identiteatel-rensjur"><div class="flex wd-100"><span class="hide-mobile-inline-mq-736px">Afficher le téléphone</span><span class="inline-block show-mobile-inline-mq-736px">Afficher le numéro</span></div></div><div class="isHidden flex flex-nowrap" id="aboutement-rensjur"><div class="wd-100 shrink"><div class="aboutement-ctr" id="telab-rensjur"><i class="material-icons">call</i><strong class="aboutement-num" id="telab-rensjur-num"></strong><div class="aboutement-info" id="telab-rensjur-info"><span>Service <em class="isHidden normal">gratuit</em><b>2,99€/appel</b></span><span>+ prix appel</span></div></div><div class="aboutement-price-details pt-2" id="price_details-rensjur"></div></div><div class="compteplus tvaAffiliationDesktop newoffers isHidden" id="aboutement-tel-affiliation-desktop"><div class="compteplus historiqueDonneesAffiliationDesktop newoffers"><div class="AutopromoPlus__promo inTable newoffers"><span class="AutopromoPlus__icon"><i class="material-icons-outlined">rocket_launch</i></span><p class="AutopromoPlus__text">Version limitée. Pour en voir plus, faites évoluer votre offre. </p><p class="flex center"><a class="CtaButton text reverse mr-8" href="https://paiement.societe.com/cgi-bin/compte-login">Se connecter</a><a class="CtaButton reverse" href="/offres.html" onclick="gana_event(this.href, 'Conversion', 'SocietePlus', 'aboutement tel'); return false;">Découvrir</a></p></div></div></div></div></td></tr><tr class="isHidden" id="aboutement-tel-affiliation-mobile"><td class="tvaAffiliationMobile no-padding"></td><td class="tvaAffiliationMobile no-padding"><div class="compteplus"><div class="AutopromoPlus__promo inTable newoffers"><span class="AutopromoPlus__icon"><i class="material-icons-outlined">rocket_launch</i></span><p class="AutopromoPlus__text">Version limitée. Pour en voir plus, faites évoluer votre offre. </p><p class="flex center"><a class="CtaButton text reverse mr-8" href="https://paiement.societe.com/cgi-bin/compte-login">Se connecter</a><a class="CtaButton reverse" href="/offres.html" onclick="gana_event(this.href, 'Conversion', 'SocietePlus', 'aboutement tel'); return false;">Découvrir</a></p></div></div></td></tr></table>,
#  <table class="Table identity" id="rensjurcomplete" style="display:none;"><tr class="bg-soPrimaryColor2-25 no-bt"><td colspan="2"><span class="soBaseColor-700 ft-medium">Juridiction</span></td></tr><tr><td class="arrow">Greffe du</td><td>Coutances (Tribunal de commerce)</td></tr><tr><td class="arrow">N° dossier</td><td>2007B00508</td></tr><tr><td class="arrow">Code greffe</td><td>5002</td></tr><tr class="bg-soPrimaryColor2-25"><td colspan="2"><span class="soBaseColor-700 ft-medium">Adressage complet</span></td></tr><tr><td class="arrow">Nom d'usage</td><td>FRANCE CROCO</td></tr><tr><td class="arrow">Adresse (RCS)</td><td>ZONE ARTISANALE MARE AUX RAINES</td></tr><tr><td class="arrow">Code postal (RCS)</td><td>50190</td></tr><tr><td class="arrow">Ville (RCS)</td><td>PERIERS</td></tr><tr><td class="arrow">Pays (RCS)</td><td>France</td></tr><tr><td class="arrow">Adresse (INSEE)</td><td>ZA LA MARE AUX RAINES NORD</td></tr><tr><td class="arrow">Code postal (INSEE)</td><td>50190</td></tr><tr><td class="arrow">Ville (INSEE)</td><td>PERIERS</td></tr><tr><td class="arrow">Pays (INSEE)</td><td>France</td></tr></table>,
#  <table class="Table leader" id="dir2"><tr><td class="arrow">Depuis le 04-01-2022 </td><td><a class="Lien" href="https://dirigeant.societe.com/dirigeant/Michel.HAUTEKIET.53006212.html"><span>M Michel HAUTEKIET</span></a></td><td class="txt-right"><p><a class="Lien with-picto inside float-right" href="https://dirigeant.societe.com/dirigeant/Michel.HAUTEKIET.53006212.html"><span> En savoir <i class="material-icons-outlined">add</i></span></a></p></td></tr></table>,
#  <table class="Table leader mt-16" id="dir2complete" style="display:none;"><tr><td class="arrow">Nom</td><td>HAUTEKIET</td></tr><tr><td class="arrow">Prénom</td><td>Michel, Guy, Jean</td></tr><tr><td class="arrow">Année de naissance</td><td>1961</td></tr><tr><td class="arrow">Dernière info. en date</td><td>04-01-2022</td></tr></table>,
#  <table class="Table leader" id="dir9"><tr><td class="arrow">Depuis le 18-08-2022 </td><td><a class="Lien" href="https://dirigeant.societe.com/dirigeant/Riccardo.MATTIOLI.78367120.html"><span>M Riccardo MATTIOLI</span></a></td><td class="txt-right"><p><a class="Lien with-picto inside float-right" href="https://dirigeant.societe.com/dirigeant/Riccardo.MATTIOLI.78367120.html"><span> En savoir <i class="material-icons-outlined">add</i></span></a></p></td></tr></table>,
#  <table class="Table leader mt-16" id="dir9complete" style="display:none;"><tr><td class="arrow">Nom</td><td>MATTIOLI</td></tr><tr><td class="arrow">Prénom</td><td>Riccardo</td></tr><tr><td class="arrow">Année de naissance</td><td>1977</td></tr><tr><td class="arrow">Dernière info. en date</td><td>18-08-2022</td></tr></table>,
#  <table class="Table pack mb-24" id="statutshoptable"><tr class="head"><th colspan="3">Statuts numérisés</th><td class="p-0 txt-right noClick" colspan="2"><a class="Lien" href="javascript:void(0);" onclick="pc_onclicktd('/docs/statuts_exemple.pdf');"><span>Voir un exemple</span></a></td></tr><tr class="" data-prodcat="54 - Acte" data-prodnum="6" data-prodprice="7,90" data-prodstr="LTMyNDk6Mzk5OvlNLOGyiVtBvLEHSIGae2RGK5NaYIVAqq49hRwqRHkF5Cmz6rWYvROZjcJQFbBRoKMn8wJ5JoQ2A50CAgIBoEloqjk4U6FpWGecIbrliPFoEx8rv5SMxkxYyfE3glhwAfkYyyiiCxxoSYrV8wYSrJIhFQoAegsiZeSpEkiFS9UWEIMJKBDnGyd7QmhAlQgzLiGOVUFfk9Rd6-6peFnYmySaQbACRmtBnDJWlrxHLENPolN0TlHPzmwID0Jjsq8ZxqRALX-eQQlIdUuoTGJAvIW-ZYM1GkkCjSkXBaGibASOqgm-IZxgneDQKVaSYIsAJMZZAUwSBKBLkBJKQgWgCC55ViGQCHrDh8wcyyGxQXiGIHyJ2e6iJ1_sBriAgDFdA1oKogTIw2CkKVkxLugeJQaI4ItoVWQgRCA-kEgASYNBUUmx9CJingExm_aVCI-C0TyP4JtplOQYZTfEdZy-8QOMwhmtEYwhczNf34MvhCwocIEIFBdNNkv2acM0SWmv3Iuhm4MOtCVoM7qGosGJbw" data-prodzone="fiche" id="6"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="05/07/2022">05/07<span>2022</span></time></td><td class="ft-medium">Statuts mis à jour - Traité de fusion - Décision(s) de l'associé unique - Modification(s) statutaire(s) - Décision(s) de l'associé unique - Ancienne valeur : TANNERIE DE PERIERSNouvelle valeur : FRANCE CROCO - Décision(s) de l'associé unique - Fusion définitive</td><td class="ft-bold txt-right"><span class=""> 7,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn6">shopping_cart</i><span class="basket-add" id="ico-plus6"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check6"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add6">Ajouté</span><span class="isHidden" data-state="0" id="check6"></span></div></td></tr></table>,
#  <table class="Table pack mb-24" id="eventshoptable"><tr class="head"><th colspan="3"> Les derniers actes modificatifs numérisés <span class="float-right"></span></th><th class="p-0 txt-right noClick" colspan="2"><a class="Lien" href="javascript:void(0);" onclick="pc_onclicktd('/docs/acte_exemple.pdf');"><span>Voir un exemple</span></a></th></tr><tr class="xIsProduct" data-prodcat="54 - Acte" data-prodprice="7,90" data-prodstr="NTczOToyNjE6-U0s4bKJW0G8sQdIgZp7ZDZeyZh_a0C-uVQBDfJGkpBm6vw8hVJUgYQ3rUGDMTELcDkCBLTp3AQCNDcKcE2lzVMQAgIZrFIi3EIgwCkpzJmaFYxieCBpwo6Zs1ZG6SDDgRrWhNePUrChqfLCGhOx2W-XOINWzHD12aNomKQESgk8BggGE1IouWgJDlMygCO5G5KBFEEkk-NtyAYF9XjaWjRBoAIZRBT4aOF9Q184cU0xqBhxW4NwGOwQQikLCYFHGwRAgHR8OEUe4dLrCoESGFEFsFK9EkMyRghQRPGCAJLRIcUaGoajSmbFcMBpzMhZZ4RQwe4P4I7AY7H4eqUK-QrgQQoN" data-prodzone="fiche" id="0" prodnum="0"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="08/06/2023">08/06<span>2023</span></time></td><td class="ft-medium">Décision(s) de l'associé unique - Reconstitution de l'actif net</td><td class="ft-bold txt-right"><span class=""> 7,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn0">shopping_cart</i><span class="basket-add" id="ico-plus0"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check0"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add0">Ajouté</span><span class="isHidden" data-state="0" id="check0"></span></div></td></tr><tr class="xIsProduct" data-prodcat="54 - Acte" data-prodprice="7,90" data-prodstr="-ADR1obQQCJvQkvFFpcKXIACdJQoBOwJdOGA3l8IBE7yHFu-DcsHOVEOlcsowZRjdhECHISfNJPDGhygquIO2S270i7-VfFYoErQSzVhpA" data-prodzone="fiche" id="1" prodnum="1"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="16/08/2022">16/08<span>2022</span></time></td><td class="ft-medium">Décision(s) de l'associé unique - Changement de directeur général</td><td class="ft-bold txt-right"><span class=""> 7,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn1">shopping_cart</i><span class="basket-add" id="ico-plus1"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check1"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add1">Ajouté</span><span class="isHidden" data-state="0" id="check1"></span></div></td></tr><tr class="xIsProduct isInvisible" data-prodcat="54 - Acte" data-prodprice="7,90" data-prodstr="MTgxMTY6MzAzOvlNLOGyiVtBvLEHSIGae2RGrgvYSCM4it3kBBrVgqq_GHnPCsxicA9LDj2t48RUK-M1EADLDYVzTiQwLzhEsWJZUQFdQowoeTkaAEAqRBAP4ETdlQSKASUDxA1qtRIB0z7AfG6A4JelIzEMAxiRGnzFZZw4BEV6Vd1JWFl1paKDHLFxEK8SLYhbIgQTSTwlPIGLKJCUIiGOwPMGYhcIM5sWLUhBIGWzOiBCSN4ECvAMrlAWojZQMgQieBANPBhTEc_FRjCghMPIXHWT4y3BdoOloRAORY1ogTEAGtJkw8GRLxSEVtQKoJFrUa3V7yFdgDUvMlUcEGFYcVfgkbJenEAcbBFdq-SDlgcDHdFIuRhS00CBwA8ErGRWWfAKKezzLXE3zMhyUUmaqRrUlxSUtQ" data-prodzone="fiche" id="2" prodnum="2"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="29/07/2022">29/07<span>2022</span></time></td><td class="ft-medium">Extrait de décision(s) de l'associé unique - Changement de commissaire aux comptes titulaire et suppléant</td><td class="ft-bold txt-right"><span class=""> 7,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn2">shopping_cart</i><span class="basket-add" id="ico-plus2"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-chec ...
#  <table class="Table pack mb-24" id="compteshoptable"><tr class="head"><th colspan="3"> Les derniers comptes annuels numérisés </th><td class="p-0 txt-right noClick" colspan="2"><a class="Lien" href="javascript:void(0);" onclick="pc_onclicktd('/docs/comptes_exemple.pdf');"><span>Voir un exemple</span></a></td></tr><tr class="xIsProduct" data-prodcat="55 - Bilan" data-prodnum="36" data-prodprice="13,90" data-prodstr="LTE4MTY6MTgzOvmM7gdtpcIc-JgUeLojCWhhqyd1KLcJLNUBT8lEIooOKCMHQPBdY3KmQhBQkibUJ-ClmroFUrzVeA4sb4slqZOpV8LDGayOIB96dqCo4KRdgY8A8HB6EtCtCChgpiOHcR4JwBmwpCwcoLzAg-Tp2FBrBEMOUI48k5jgSipGPnh8gBYQsAaYlkiopYJygl6DNCYNOZImwQcdh0gnCggKTENjLgAwa1OL0CGTwz0kj6Fb8_LuQA47DA" data-prodzone="" id="36"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="31/12/2021">31/12<span>2021</span></time></td><td class="ft-medium">Comptes annuels complets : Complets<br/><span class="ft-regular fs-11 soBaseColor-600">(Bilan, annexes, rapport de gestion, rapport du CAC, état des créances, ...)</span></td><td class="ft-bold txt-right"><span class=""> 13,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn36">shopping_cart</i><span class="basket-add" id="ico-plus36"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check36"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add36">Ajouté</span><span class="isHidden" data-state="0" id="check36"></span></div></td></tr><tr class="xIsProduct" data-prodcat="55 - Bilan" data-prodnum="37" data-prodprice="13,90" data-prodstr="LTIxNjczOjE4Mzr5jO4HbaXCHPiYFHi6IwloYasndii3KVaAQNIJJaJ1ggJw4AdoF1in2MkgUAiYdIQ71FKzXWlGNQIgJJfszKmTqVfCwxmsjBCvqYTsFCHECwVwAOHmTC4oMhwhh7ltolirQdW_Vh1XaMBKGCGDIdOYFi04gAQicAqQEtKl0IU-AoIkSEBDgLWheyUykAcpR2jscClZMY_Q2JjDxUCEjo2Mtq6cBMILek4Y0nvYERJAsNW4egIcA9o" data-prodzone="" id="37"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="31/12/2020">31/12<span>2020</span></time></td><td class="ft-medium">Comptes annuels complets : Complets<br/><span class="ft-regular fs-11 soBaseColor-600">(Bilan, annexes, rapport de gestion, rapport du CAC, état des créances, ...)</span></td><td class="ft-bold txt-right"><span class=""> 13,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn37">shopping_cart</i><span class="basket-add" id="ico-plus37"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check37"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add37">Ajouté</span><span class="isHidden" data-state="0" id="check37"></span></div></td></tr><tr class="xIsProduct isInvisible" data-prodcat="55 - Bilan" data-prodnum="38" data-prodprice="13,90" data-prodstr="MjA1MDA6MTgzOvmM7gdtpcIc-JgUeLojCWhhqyd3UBUySHfClvZpoW25AMGHKA5IUPPMlSxhQMynjK9qLABlkUY1AiAkl-zMqZOpV8LDGUxFUEEmMNCjCeVh77EJGJARaaQzCKCCQ1sWGR3YHeUpNUkGADoDGlDNoU2xiRYwg2rCTjKASipGPnh8gBYYYIXE7XJuQlGaQAso6LGoU2FiABmND1ChCxjoxoli0gIJZbWJDxSivg5JyZlLNcu2wQGUhg" data-prodzone="" id="38"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="31/12/2019">31/12<span>2019</span></time></td><td class="ft-medium">Comptes annuels complets : Complets<br/><span class="ft-regular fs-11 soBaseColor-600">(Bilan, annexes, rapport de gestion, rapport du CAC, état des créances, ...)</span></td><td class="ft-bold txt-right"><span class=""> 13,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn38">shopping_cart</i><span class="basket-add" id="ico-plus38"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check38"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add38">Ajout ...
#  <table class="Table keys mb-8" id="chiffrecle"><tr class="head"><th>Date de publication de l'exercice</th><th class="txt-right">2023</th><th class="txt-right">31-12-2022</th><th class="txt-right">Variation</th></tr><tr class="Table__leader__title"><td>Total du Bilan (Actif / Passif)</td><td class="numdisplay txt-right" data-chiffre=" "></td><td class="numdisplay txt-right" data-chiffre="30171300 EU">30171300 EU</td><td class="txt-right">- - -</td></tr><tr><td class="arrow"><i class="i-right-open-big"></i>dont Trésorerie</td><td class="txt-right"></td><td class="txt-right"><a class="Lien" href="/bilan/france-croco-501737761202212311.html"><span>Voir le détail du bilan</span></a></td><td></td></tr><tr><td class="arrow"><i class="i-right-open-big"></i>dont Capitaux propres</td><td class="numdisplay txt-right" data-chiffre="Comptes non disponibles ">Comptes non disponibles </td><td class="numdisplay txt-right" data-chiffre="13129200 EU">13129200 EU</td><td class="txt-right">- - -</td></tr><tr><td class="arrow"><i class="i-right-open-big"></i>dont Dettes</td><td class="txt-right"></td><td class="txt-right"><a class="Lien" href="/bilan/france-croco-501737761202212311.html"><span>Voir le détail du bilan</span></a></td><td></td></tr><tr class="Table__leader__title border-white"><td>Chiffre d'affaires</td><td class="txt-right"><a class="Lien with-picto top" href="https://paiement.societe.com/publication-bilan.html"><span class="hide-mobile-inline-s">Publier bilan</span><span class="show-mobile-inline-s">Publier votre dernier bilan</span><i class="material-icons-outlined">file_upload</i></a></td><td class="numdisplay txt-right" data-chiffre="11338600 EU">11338600 EU</td><td class="txt-right">- - -</td></tr><tr class="Table__leader__title border-white"><td>Résultat net (Bénéfice ou Perte)</td><td class="numdisplay txt-right" data-chiffre=" "></td><td class="numdisplay txt-right" data-chiffre="-2236300 EU">-2236300 EU</td><td class="txt-right">- - -</td></tr><tr class="Table__leader__title"><td>Effectifs moyens</td><td class="numdisplay txt-right" data-chiffre=""></td><td class="numdisplay txt-right" data-chiffre="Non precise">Non precise</td><td class="txt-right">- - -</td></tr></table>,
#  <table class="Table pack mb-8" id="bodacctable"><tr class="head"><th></th><th>Date</th><th>Annonces légales (BODACC)</th><th class="txt-right"><span class=""> Prix </span></th><th class="txt-right">Achat</th></tr><tr class="xIsProduct" data-prodcat="48 - Bodacc" data-prodnum="42" data-prodprice="2,90" data-prodstr="MTM3OTE6OTg6_ZjZB22lwhz4mBR4uiMJaOElk4A3TE7V_KE8XTolZcMEgxrgN4RrSJFkAg613h0ZXDHheUscwkIxCaCexzhIAU6hQ6UvJiJC00l4B00TQijCre_22ZbQj9tQa2bDAxRVCT0" data-prodzone="fiche" id="42"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="31/12/2022">31/12<span>2022</span></time></td><td class="ft-medium">Annonce BODACC - Comptes annuels et rapports (31/12/2022)</td><td class="ft-bold txt-right"><span class=""> 2,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn42">shopping_cart</i><span class="basket-add" id="ico-plus42"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check42"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add42">Ajouté</span><span class="isHidden" data-state="0" id="check42"></span></div></td></tr><tr class="xIsProduct" data-prodcat="48 - Bodacc" data-prodnum="43" data-prodprice="2,90" data-prodstr="LTE0MTY3OjkyOvkN_DpBqCWbBDCLBRJ6EswaRuAAJ1MiVNcRoQWmiBBzwW7gCgzlMtQUkOCD2HVRhDJY0RHRDmouklVBhNAQ4VapVSjAEmeoVWeIMDZ45EYmOKWEdiwhZKWvkTTB" data-prodzone="fiche" id="43"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="22/09/2022">22/09<span>2022</span></time></td><td class="ft-medium">Annonce JAL - Mouvement des Dirigeants</td><td class="ft-bold txt-right"><span class=""> 2,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn43">shopping_cart</i><span class="basket-add" id="ico-plus43"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check43"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add43">Ajouté</span><span class="isHidden" data-state="0" id="check43"></span></div></td></tr><tr class="link table-voir-plus" id="bodaccall"><td colspan="5"><a class="Lien with-picto" href="/documents-officiels/france-croco-501737761.html#statutshop"><span>Voir toutes les annonces légales</span><i class="material-icons-outlined">expand_more</i></a></td></tr><tr class="xIsProduct" data-prodcat="48 - Bodacc" data-prodnum="44" data-prodprice="2,90" data-prodstr="MTA1Mzc6OTc6_ZjZB22lwhz4mBR4uiMJaOElk4BJQ9O6d1AEAm0fcDpo2CDLCypaJcJcR38hJNkh8aeUPUGHZIlTZUJwqBrpFODAppAoiIzV4NQEALjJRmBR0HbojCAuihnpalYlhlGy7g" data-prodzone="fiche" id="44"><td class="pic"><img src="https://imgng.societe.com/img/picto_pdf_G.png"/></td><td class="docdate"><time datetime="31/12/2007">31/12<span>2007</span></time></td><td class="ft-medium">Annonce BODACC - Immatriculation d'une personne morale (B, C, D) suite à création d'un établissement principal</td><td class="ft-bold txt-right"><span class=""> 2,90€ </span></td><td class="basket"><div class="flex center flex-wrap pt-3"><i class="material-icons-outlined" id="pn44">shopping_cart</i><span class="basket-add" id="ico-plus44"><i class="material-icons">add_circle</i></span><span class="basket-check isInvisible" id="ico-check44"><i class="material-icons">check_circle</i></span><span class="basket-notif" id="add44">Ajouté</span><span class="isHidden" data-state="0" id="check44"></span></div></td></tr></table>]

# %%
tables_rows[0]
# Out:
# <table class="Table identity mt-16" id="rensjur"><tr><td class="arrow">Date création entreprise</td><td class="flex space-between flex-wrap"><div class="TableTexteGauche"><span class="TableTextGenerique"> 17-12-2007 </span><span class="TableTextDetail"><span class="show-mobile-inline-l"> - </span>il y a 16 ans </span></div><span class="TableLienDroite"><a class="Lien with-picto" href="https://www.societe.com/documents-officiels/france-croco-501737761.html#statutshop"><span>Statuts constitutifs</span><i class="material-icons-outlined">chevron_right</i></a></span></td></tr><tr class="Paywall"><td class="arrow" colspan="2"><div class="FicheDonnees__around imrFirst" id="catjur-histo-around"><div class="FicheDonnees" id="catjur-histo" onclick="show_historique_donnees('catjur-histo-voir')"><div class="abonne-compteplus donneesHistoriques voirPlus" id="catjur-histo-voir"><p class="Lien with-picto"><span class="hide-mobile-inline-l">Historique</span><span class="show-mobile-inline-l">Voir l'historique</span><i class="material-icons-outlined">expand_more</i></p></div><div class="FicheDonnees__libelle">Forme juridique </div><div class="FicheDonnees__donneeGenerique ml-6" id="catjur-histo-description">SASU Société par actions simplifiée à associé unique </div><div class="FicheDonnees__donneeGenerique soPrimaryColor2 ml-6 isHidden" id="catjur-histo-libelle">Historique </div></div><div class="FicheDonnees__historique noOpacity nocompteplus" id="catjur-histo-content"><div class="histo-part" id="catjur-histo-content-src-rcs"><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du 11-11-2016</p><p>à aujourd'hui </p><p class="soBaseColor-600 italic">7 ans, 1 mois et 21 jours </p></div><div class="FicheDonnees__timeline first"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description first newoffers"><span class="description-txt">SASU Société par actions simplifiée à associé unique</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXXX X XXXX XX XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXXX X XXXX XX XX XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="FicheDonnees__item"><div class="FicheDonnees__date"><p>Du XX-XX-XXXX</p><p>au XX-XX-XXXX </p><p class="soBaseColor-600 italic">X XXX XX X XXXXX </p></div><div class="FicheDonnees__timeline"><div class="line"></div><div class="cercle"></div></div><div class="FicheDonnees__description newoffers"><span class="description-txt">S.......</span></div></div><div class="compteplus historiqueDonneesAffiliationDesktop newoffers"><div class="AutopromoPlus__promo inTable newoffers"><span class="AutopromoPlus__icon"><i class="material-icons-outlined">rocket_launch</i></span><p class="AutopromoPlus__text">Version limitée. Pour en voir plus, faites évoluer votre offre. </p><p class="flex center"><a class="CtaButton text reverse mr-8" href="https://paiement.societe.com/cgi-bin/compte-login">Se connecter</a><a class="CtaButton reverse" href="/offres.html" onclick="gana_event(this.href, 'Conversion', 'SocietePlus', 'catjur imr ...

# %%
datas = []
for table in tables_rows:
    df = pd.read_html(str(table))
    datas.append(df)
# Out:
# /tmp/ipykernel_43633/1605355544.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_43633/1605355544.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_43633/1605355544.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 datas = []
#       2 for table in tables_rows:
# ----> 3     df = pd.read_html(str(table))
#       4     datas.append(df)
#
# File ~/.cache/pypoetry/virtualenvs/scraping-societe-GP-apnY6-py3.9/lib/python3.9/site-packages/pandas/io/html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
#    1246     flavor=flavor,
#    1247     io=io,
#    1248     match=match,
#    1249     header=header,
#    1250     index_col=index_col,
#    1251     skiprows=skiprows,
#    1252     parse_dates=parse_dates,
#    1253     thousands=thousands,
#    1254     attrs=attrs,
#    1255     encoding=encoding,
#    1256     decimal=decimal,
#    1257     converters=converters,
#    1258     na_values=na_values,
#    1259     keep_default_na=keep_default_na,
#    1260     displayed_only=displayed_only,
#    1261     extract_links=extract_links,
#    1262     dtype_backend=dtype_backend,
#    1263     storage_options=storage_options,
#    1264 )
#
# File ~/.cache/pypoetry/virtualenvs/scraping-societe-GP-apnY6-py3.9/lib/python3.9/site-packages/pandas/io/html.py:1008, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#    1006 else:
#    1007     assert retained is not None  # for mypy
# -> 1008     raise retained
#    1010 ret = []
#    1011 for table in tables:
#
# File ~/.cache/pypoetry/virtualenvs/scraping-societe-GP-apnY6-py3.9/lib/python3.9/site-packages/pandas/io/html.py:988, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     977 p = parser(
#     978     io,
#     979     compiled_match,
#    (...)
#     984     storage_options,
#     985 )
#     987 try:
# --> 988     tables = p.parse_tables()
#     989 except ValueError as caught:
#     990     # if `io` is an io-like object, check if it's seekable
#     991     # and try to rewind it before trying the next parser
#     992     if hasattr(io, "seekable") and io.seekable():
#
# File ~/.cache/pypoetry/virtualenvs/scraping-societe-GP-apnY6-py3.9/lib/python3.9/site-packages/pandas/io/html.py:248, in _HtmlFrameParser.parse_tables(self)
#     240 def parse_tables(self):
#     241     """
#     242     Parse and return all tables from the DOM.
#     243
#    (...)
#     246     list of parsed (header, body, footer) tuples from tables.
#     247     """
# --> 248     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     249     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/.cache/pypoetry/virtualenvs/scraping-societe-GP-apnY6-py3.9/lib/python3.9/site-packages/pandas/io/html.py:621, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, document, match, attrs)
#     619     unique_tables.add(table)
#     620 if not result:
# --> 621     raise ValueError(f"No tables found matching pattern {repr(match.pattern)}")
#     622 return result
#
# ValueError: No tables found matching pattern '.+'

# %%
# 3 send enterprise data to array
for i in urlList:
    for j in range(startYear, endYear):
        url = i+f"{j}12311.html"
        print(j)
        print(url)
        datas = []
        urlText = gen_soup(url)
        tables_rows = urlText.findAll('table')
        for table in tables_rows:
            df = pd.read_html(str(table))
            datas.append(df)
        # get enterprise name
        placeSlash = i.rfind('/')+1
        placeDash = i.rfind('-')
        enterprise  = i[placeSlash:placeDash]
        my_ent.append(enterprise)
        infoSend  = {
            'enterprise':  enterprise, 
            'year':j, 
            'data':datas
            }
        #Send to global Array container
        globalDf.append(infoSend)
    # display(globalDf)
# Out:
# 2018
# https://www.societe.com/bilan/hugel-et-fils-sa-915722144201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/hugel-et-fils-sa-915722144201912311.html
# 2018
# https://www.societe.com/bilan/maison-louis-jadot-403231137201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/maison-louis-jadot-403231137201912311.html
# 2018
# https://www.societe.com/bilan/caves-bailly-lapierre-778681122201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/caves-bailly-lapierre-778681122201912311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2018
# https://www.societe.com/bilan/union-des-vignerons-des-cotes-du-rhone-302558622201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/union-des-vignerons-des-cotes-du-rhone-302558622201912311.html
# 2018
# https://www.societe.com/bilan/sca-les-vignerons-du-val-d-orbieu-775812258201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/sca-les-vignerons-du-val-d-orbieu-775812258201912311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2018
# https://www.societe.com/bilan/chateau-de-santenay-412618001201812311.html
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# /tmp/ipykernel_33251/2792418180.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))
# 2019
# https://www.societe.com/bilan/chateau-de-santenay-412618001201912311.html
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       6 print(url)
#       7 datas = []
# ----> 8 urlText = gen_soup(url)
#       9 tables_rows = urlText.findAll('table')
#      10 for table in tables_rows:
#
# Cell In[2], line 21, in gen_soup(url)
#      19 def gen_soup(url):
#      20     req = Request(url, headers={'User-Agent': 'Safari'}) # changer le navigateur éventuellement (ça ne change pas grand chose)
# ---> 21     webpage = urlopen(req).read()
#      22     return bs(webpage,"html.parser")
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
